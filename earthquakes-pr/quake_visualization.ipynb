# %%
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt


pr = folium.Map(location=[18.2208, -66.5901],
                zoom_start=9,
                tiles='cartodbdark_matter'
               )

df = pd.read_csv('query45.csv',
                 usecols=['latitude', 'longitude','place', 'mag'],
                )
pr
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
df
# Out:
#     latitude  longitude   mag                                   place
# 0    18.9836   -67.1885  4.78      51km N of San Antonio, Puerto Rico
# 1    17.9371   -66.8661  4.70        11km SSE of Guanica, Puerto Rico
# 2    17.8846   -66.8640  5.00            9km S of Indios, Puerto Rico
# 3    17.9308   -66.8363  4.70  11km SSE of Maria Antonia, Puerto Rico
# 4    17.9148   -66.8333  4.50           13km S of Indios, Puerto Rico
# 5    17.9006   -66.8261  4.70            8km S of Indios, Puerto Rico
# 6    17.8675   -66.8193  5.80          9km SSE of Indios, Puerto Rico
# 7    17.9075   -66.7990  4.90        8km SSW of Tallaboa, Puerto Rico
# 8    17.8672   -66.8280  6.40  13km SSE of Maria Antonia, Puerto Rico
# 9    17.8574   -66.7315  5.00         15km S of Tallaboa, Puerto Rico
# 10   17.9206   -66.7670  4.60           9km SE of Indios, Puerto Rico
# 11   17.8919   -66.7217  5.60         11km S of Tallaboa, Puerto Rico
# 12   17.9418   -66.6754  5.00         7km SE of Tallaboa, Puerto Rico
# 13   17.9128   -66.6898  4.70        9km SSE of Tallaboa, Puerto Rico
# 14   18.0223   -66.7760  5.60        9km SSW of Tallaboa, Puerto Rico
# 15   17.9998   -66.7491  4.50     2km SE of Magas Arriba, Puerto Rico
# 16   17.9315   -66.9270  4.70           3km S of Guanica, Puerto Rico
# 17   18.0136   -66.7501  4.50        5km ESE of Tallaboa, Puerto Rico
# 18   17.9645   -66.8256  4.60         6km SW of Tallaboa, Puerto Rico
# 19   17.9150   -66.7035  4.70        7km SSE of Tallaboa, Puerto Rico
# 20   17.9350   -66.8830  5.20          4km SSW of Indios, Puerto Rico
# 21   17.9923   -66.7946  4.80      2km S of Magas Arriba, Puerto Rico
# 22   17.9490   -66.8508  5.90         11km SSE of Indios, Puerto Rico
# 23   17.8238   -66.7941  5.20           19km S of Indios, Puerto Rico
# 24   17.9423   -66.8395  4.60         11km SSE of Indios, Puerto Rico
# 25   17.9556   -66.8865  4.90          1km SW of Palomas, Puerto Rico
# 26   17.9033   -66.8765  4.50        10km SSE of Guanica, Puerto Rico
# 27   17.9638   -66.8131  4.50           11km S of Indios, Puerto Rico
# 28   17.8548   -66.8686  4.60        24km SSE of Guanica, Puerto Rico
# 29   17.9155   -67.0171  5.20         6km WSW of Guanica, Puerto Rico
# 30   17.9770   -66.7408  4.50        0km WSW of Tallaboa, Puerto Rico
# 31   17.9748   -66.7528  4.60        7km SSE of Tallaboa, Puerto Rico
# 32   17.9618   -66.7425  4.50         13km S of Tallaboa, Puerto Rico
# 33   17.9245   -66.9401  4.50        11km SSW of Guanica, Puerto Rico
# 34   18.0105   -66.8188  5.00         12km SSE of Indios, Puerto Rico
# 35   18.9538   -67.6276  4.60     76km NW of San Antonio, Puerto Rico
# 36   17.8388   -66.8751  5.00        20km SSE of Guanica, Puerto Rico
